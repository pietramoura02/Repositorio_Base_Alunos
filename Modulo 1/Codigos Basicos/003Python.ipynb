# %% [markdown]
# #string

# %% [markdown]
# São usadas principalmente para armazenar informações de texto. Nelas temos uma sequencia de caracteres que formam um texto. O Python permite formar strings com aspas simples ou duplas.

# %%
"Pietra"=="PIETRA" # o Python diferencia letras maiusculas de minusculas
# Out:
# False

# %%
nome = "pietra"
sobrenome = "moura"
print (nome+ " " + sobrenome)
# Out:
# pietra moura

# %% [markdown]
# #F-strings

# %% [markdown]
# string literais formatadas

# %%
idade = 15

# %%
print(nome, sobrenome, idade) # as virgulas são maneiras de chamar variaveis diferentes
# Out:
# pietra moura 15

# %%
print(f" {nome} {sobrenome} tem {idade} anos.") # f na frente do print informa que estamos formatando o print
# Out:
#  pietra moura tem 15 anos.

# %%
linguagem = "Python"
print(f"eu adoro pregamar em {linguagem}. E, amo mais ainda ganhar muito $$ programando em python.")
# Out:
# eu adoro pregamar em Python. E, amo mais ainda ganhar muito $$ programando em python.

# %% [markdown]
# # String são objetos iteraveis

# %%
nome = "pietra" # o pthon entende um palavra como uma lista de letras, então podemos percorrer essa lista e capturar os elementos que desajmos # uma lista sempre inicia pelo indice ZERO

# %%
print(nome)
# Out:
# pietra

# %%
nome[0]
# Out:
# 'p'

# %%
nome[3]
# Out:
# 't'

# %%
nome[-1] # podemos acessar o ultimo elemento de um alsita atraves do indice -1
# Out:
# 'a'

# %% [markdown]
# # entrada de dado com a função input()

# %% [markdown]
# é muito comum em programação que o usuario passe algum tipo de dado

# %%
input("digite seu nome: ")
# Out:
# digite seu nome: Pietra
# 'Pietra '

# %%
nome = input("digite eu nome: ")
# Out:
# digite eu nome: pietra

# %%
print(nome)
# Out:
# pietra

# %%
# para fzer uma operção matematica precisamos informar qual é o tipo de dado
num1= input("digite um numero: ")
num2= input("digite outro numero: ")
print(num1 + num2)
# Out:
# digite um numero: 25
# digite outro numero: 38
# 2538

# %%
# para fzer uma operção matematica precisamos informar qual é o tipo de dado
num1 =int(input("digite um numero: "))
num2 =int(input("digite outro numero: "))
print(num1 + num2)
# Out:
# digite um numero: 98
# digite outro numero: 0
# 98

# %%
soma = num1 + num2
print(soma)
# Out:
# 98

# %%
nota1 = float(input("digite a primeira nota: "))
nota2 = float(input("digite a segunda nota: "))
media = (nota1 + nota2)/2
print(f"o aluno(a teve notas {nota1}, {nota2} e sua media {media}. ")
# Out:
# digite a primeira nota: 6
# digite a segunda nota: 8
# o aluno(a teve notas 6.0, 8.0 e sua media 7.0.

# %% [markdown]
# # Operadores aritimeticos

# %% [markdown]
# adição(+)

# %%
print(10 + 20)
print(10+20.5)
print(10 + 30 + 40)
# Out:
# 30
# 30.5
# 80

# %%
print(-89 + 63) # print é uma função de saida no python
print(23 - 17) # 23 + (-17)
print( 23 + (-17))
print(34 - 67) # 34 + (-67)
# Out:
# -26
# 6
# 6
# -33

# %% [markdown]
# ## Subtração (-)

# %%
print(123-87)
# Out:
# 36

# %% [markdown]
# ## multiplicação (*)

# %%
print(10*2)
# Out:
# 20

# %%
print(2.4 * 2.5)
# Out:
# 6.0

# %% [markdown]
# ## DIvisão (/)

# %%
print(1000/10)
print(129/23)
# Out:
# 100.0
# 5.608695652173913

# %% [markdown]
# ## Divisão com resultado inteiro (//)

# %%
print(129//23)
# Out:
# 5

# %% [markdown]
# ## exponenciação

# %%
print(2**3)
# Out:
# 8

# %%
print(2**-1)
# Out:
# 0.5

# %%
print(2**-1.5)
# Out:
# 0.3535533905932738

# %% [markdown]
# ## Precedencia

# %% [markdown]
# 1. Parenteses
# 2. expoentes
# 3. Multiplicação
# 4. divisão (da squerda para direita)
# 5. somas e subtração

# %%
5 + 25 * 2
# Out:
# 55

# %%
(5 + 25) * 2
# Out:
# 60

# %%
(12 + 3 - 1 * 50/3)
# Out:
# -1.6666666666666679

# %% [markdown]
# ## Radiação

# %%
4 ** 0.5
# Out:
# 2.0

# %% [markdown]
# # Hora da pratica

# %% [markdown]
# 1) Crie um codigo que receba o nome do aluno, duas notas e informe a media do aluno. Obs: no seu print apresente o nome do aluno, as duas notas e a media.

# %%
nota1 = float(input("digite a primeira nota: "))
nota2 = float(input("digite a segunda nota: "))
media = (nota1 + nota2)/2
print(f"o aluno(a) teve notas {nota1}, {nota2} e sua media {media}. ")
# Out:
# digite a primeira nota: 6
# digite a segunda nota: 8
# o aluno(a teve notas 6.0, 8.0 e sua media 7.0.

# %% [markdown]
# 2) crie um codigo que receba as medidas

# %%
vertice1 = float(input("digite a altura do retangulo: "))
vertice2 = float(input("digite a largura do retangulo: "))
perimetro = (vertice1 + vertice2) *2
print(f"o perimetro do retangulo é igual a {perimetro}")
# Out:
# digite a altura do retangulo: 7
# digite a largura do retangulo: 4
# o perimetro do retangulo é igual a 22.0

# %% [markdown]
# 3) crie um codigo que calcule a raiz quadrada de um numero

# %%
num1 = float (input("Digite um numero: "))
raiz = num1 ** 0.5

print(f"a raiz quadrada do numero {num1} é {raiz}")
# Out:
# Digite um numero: 6
# a raiz quadrada do numero 6.0 é 2.449489742783178

# %% [markdown]
# 4) crie uma calculadora simples(adição, subtração, multiplicação e divisão. seu codigo deve receber 2 numeros e apresentar o resultado das 4 operações

# %%
n1= float(input("digite um numero: "))
n2= float(input("digite um novo numero:"))
soma = n1 + n2
subtração= n1 * n2
multiplicação = n1 * n2
divisão = n1/n2
print(f"{n1}, {n2} é {soma}, {subtração}, {multiplicação}, {divisão:.2f}")
# Out:
# digite um numero: 7
# digite um novo numero:8
# 7.0, 8.0 é 15.0, 56.0, 56.0, 0.88

# %% [markdown]
# 5) calcule a diferença entre dois numeros

# %%
num1= float(input("digite um numero: "))
num2= float(input("digite um novo numero: "))
subtracao= num1-num2
print(f"a diferença entre {num1} e {num2} é{subtracao}")
# Out:
# digite um numero: 7
# digite um novo numero: 4
# a diferença entre 7.0 e 4.0 é3.0

# %% [markdown]
# 6) calcule o produto entre dois numeros

# %%
num1=float(input("digite um numero (base): "))
numm2=float(input("digite outro numero (expoente): "))
produto =num1** num2
print(f"{num1} produto entre {num2} vale {potenciação}")
# Out:
# digite um numero (base): 4
# digite outro numero (expoente): 2
# 4.0 produto entre 3.0 vale 512.0

# %% [markdown]
# 7) crie um codigo que receba uma base e depois o expoente e calcule a potencia.

# %%
num1=float(input("digite um numero (base): "))
num2=float(input("digite outro numero (expoente):"))
potenciação =num1** num2
print(f"{num1} elevado ao expoente {num2} vale {potenciação}")
# Out:
# digite um numero (base): 8
# digite outro numero (expoente):3
# 8.0 elevado ao expoente 3.0 vale 512.0

# %% [markdown]
# 8) crie um programa que solicite ao usuario a quantidade de horas trabalhadas por semana e o valor da hora de trabalho e calcule o salario mensal.

# %%
horas=float(input("digite o numero de horas trabalhadas: "))
valor=float(input("digite o valor da hora trabalhada R$ "))
calculo=horas * valor
print(f"trabalhando {horas} horas voce recebera R$ {calculo:.2f}")
# Out:
# digite o numero de horas trabalhadas: 6
# digite o valor da hora trabalhada R$ 1
# trabalhando 6.0 horas voce recebera R$ 6.00
